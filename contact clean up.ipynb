# %% [markdown]
# Contact Clean Up Program
#
# Tools:
#     Table: Shows the % of contacts per record type that are using a field
#
#     Function: threshold_per_type(p,n)
#         => A table showing all the fields that are under p% usage for n number of records
#
#     Function: contact_type_using_field(r,f)
#         => A table showing all contacts of type r that are using field f
#
#     Function: contacts_using_fields_in_criteria(p,n)
#         => Gets the fields with in the given criteria. For each field, a table of the contacts using the field for each record type
#
#     Function: date_range_of_contacts(t)
#         => Given a table of contacts using a field, returns the range of the contacts

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import altair as alt
import seaborn as sns
import datetime
import tables
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
sf_contact_df = pd.read_csv('contacts.csv',  encoding = "cp1252")
sf_contact_df.to_pickle('contact.pkl')
# Out:
# c:\users\jmadubuko\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (6,7,8,11,12,13,14,15,23,24,27,30,31,32,33,34,35,37,38,39,40,41,52,55,56,57,58,64,66,67,68,70,73,74,75,76,77,80,81,83,85,87,91,92,95,96,97,98,100,101,103,105,107,108,109,110,112,114,115,116,117,118,119,120,121,122,123,124,125,127,131,134,135,136,137,138,139,140,141,142,143,144,145,146,152,158,167,170,172,174,175,176,177,178,179,181,182,183,184,185,186,187,189,190,191,194,195,196,197,201,212,217,223,224,225,226,227,230,232,233,236,239,250,251,252,261,262,263,264,265,268,269,270,274,282,292,295,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,316,317,318,319,320,321,323,325,326,327,328,329,331,333,338,339,341,342,347,348,350,352,353,354,356,357,359,360,364,375,377,394,404,413,414,415,417,418,424,426,434,437,438,439,440,441,453,455,456,458,459,462,463,464,465,466,470,471,472,473,475,476,478,479,480,481,482,483,484,485,487,489,490,491,495,496,507,508,509,514,525) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sf_contact_df.to_hdf('contact.h5', key='df', mode='w')
# Out:
# c:\users\jmadubuko\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py:1996: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block2_values] [items->['ID', 'ACCOUNTID', 'LASTNAME', 'FIRSTNAME', 'SALUTATION', 'MIDDLENAME', 'SUFFIX', 'NAME', 'RECORDTYPEID', 'OTHERSTREET', 'OTHERCITY', 'OTHERSTATE', 'OTHERPOSTALCODE', 'OTHERCOUNTRY', 'MAILINGSTREET', 'MAILINGCITY', 'MAILINGSTATE', 'MAILINGPOSTALCODE', 'MAILINGCOUNTRY', 'MAILINGGEOCODEACCURACY', 'PHONE', 'FAX', 'MOBILEPHONE', 'HOMEPHONE', 'OTHERPHONE', 'ASSISTANTPHONE', 'REPORTSTOID', 'EMAIL', 'TITLE', 'DEPARTMENT', 'ASSISTANTNAME', 'LEADSOURCE', 'DESCRIPTION', 'CURRENCYISOCODE', 'OWNERID', 'CREATEDDATE', 'CREATEDBYID', 'LASTMODIFIEDDATE', 'LASTMODIFIEDBYID', 'SYSTEMMODSTAMP', 'LASTACTIVITYDATE', 'LASTVIEWEDDATE', 'LASTREFERENCEDDATE', 'EMAILBOUNCEDREASON', 'EMAILBOUNCEDDATE', 'PHOTOURL', 'ADDRESS_TYPE__C', 'ACCOUNT_ID__C', 'ANNUAL_FIXED_ANNUITY_PRODUCTION__C', 'ANNUAL_GD__C', 'ANNUAL_VARIABLE_ANNUITY_PRODUCTION__C', 'FINRA_BROKERCHECK__C', 'ASSISTANT_S_EMAIL__C', 'BROKER_DEALER__C', 'BUSINESS_INTERESTS__C', 'CRD__C', 'CHANNEL__C', 'COMPANY__C', 'CONTACT_STAGE__C', 'CONTACT_STATUS__C', 'CONTACT_TYPE__C', 'UNIQUE_ENTERPRISE_CONTACT_ID__C', 'CURRENT_FMO__C', 'DO_NOT_CONTACT_UNTIL__C', 'DOING_BUSINESS_AS__C', 'EIN__C', 'END_DATE__C', 'GENDER__C', 'GOLDMINE_CREATED_DATE__C', 'GOLDMINE_ID__C', 'GOLDMINE_LAST_MODIFIED_DATE__C', 'IF_EMPLOYED_WITH_WHOM__C', 'INTERNAL_WHOLESALER__C', 'MARKET_SOURCES__C', 'MIDDLE_NAME__C', 'NAME__C', 'NICKNAME__C', 'OFFICE_EXT__C', 'ONBOARDING_STATUS__C', 'ORGANIZATION__C', 'PORTAL_PASSWORD__C', 'PREFERRED_CONTACT_METHOD__C', 'PREFERRED_INSURANCE_CARRIERS__C', 'PREFERRED_PRODUCTS__C', 'PRINCIPAL__C', 'PRODUCER_WEBSITE__C', 'REASON__C', 'RECRUITER__C', 'SSN_LAST_4__C', 'SSN_TBDEL__C', 'SALESFORCE_USER_ID__C', 'SEGMENTATION__C', 'SERVICE_LEVEL__C', 'START_DATE__C', 'TERRITORY__C', 'WEDDING_ANNIVERSARY__C', 'LICENSE_RESIDENT_STATE__C', 'PREFERRED_PHONE__C', 'STATE__C', 'CONVERSION_PROGRAM__C', 'CONVERSION_PROGRAM_DATE__C', 'RECORD_TYPE_STRING__C', 'OWNER_ID_STRING__C', 'SALESFORCE_OLD_ID__C', 'TERRITORY_ID_STRING__C', 'ACCOUNT_ID_STRING__C', 'MY_SEGMENT__C', 'STAFF_USER_RECORD__C', 'SALESFORCE_USER_RECORD__C', 'TERRITORY_OWNER__C', 'TERRITORY_OWNER_ID__C', 'ACTIVE_TERRITORY__C', 'TERRITORY_NAME__C', 'ELITE_PRODUCER_UNTIL__C', 'RETENTION_STAGE__C', 'ACQUISITION_STAGE__C', 'RECORD_TYPE_NAME__C', 'BROKER_DEALER_TEXT__C', 'OWNER_NAME__C', 'TERRITORY_TYPE__C', 'TERRITORY_STATUS__C', 'TERRITORY_ROLE__C', 'PRODUCER_NAME__C', 'PL__C', 'FIRST_APPOINTMENT_DATE__C', 'MSA__C', 'ACCOUNT_TEXT__C', 'AFMO_ACCOUNT__C', 'INTERNAL_WHOLESALER_TOBE__C', 'APPLICATION_MANAGER_TOBE__C', 'COST_CENTER__C', 'PERSONAL_EMAIL__C', 'TIME_ZONE__C', 'ADDRESS_TYPE_2__C', 'REPORTING_MANAGER__C', 'ROLE__C', 'TERRITORY_INSTRUCTIONS__C', 'RECRUITER_NAME__C', 'CONTRACT_COC__C', 'ALT_SOURCE__C', 'LIST_SOURCE__C', 'OTHER_EMAIL__C', 'TERRITORY_ADJUSTMENT__C', 'NSM__C', 'IPIPEOWNERID__C', 'REFERRER__C', 'ORGANIZATION_CHANGE_DETAILS__C', 'BDACTIVEDATE__C', 'CONTRACTING_WHOLESALER__C', 'CONTACT_NAME__C', 'AGENCY__C', 'APPROVED_SALES_CHANNELS__C', 'REP_LIST_REFRESH__C', 'SOCIAL_MEDIA_POLICY__C', 'BD_PERMITTED_TACTICS_NOTES__C', 'BD_APPROVED_MARKETING_MATERIAL_NOTES__C', 'STATES_W_ACTIVE_REPS__C', 'WEALTHVEST_PRODUCER_ID__C', 'PSA_REPORT__RESOURCE_NAME__C', 'FFPSAI__EXPENSEREIMBURSEMENTACCOUNT__C', 'CONTACT_AFMO__C', 'E_O_REQUIRED__C', 'SFID__C', 'BD_AGGREGATE_FIRM__C', 'COUNTY__C', 'TIME_ZONE_2__C', 'PRODUCTION_TIER__C', 'COMMISSIONS_CAN_BE_DISCUSSED__C', 'PRODUCTION_CREDITS__C', 'TACTICS_LAST_REFRESH__C', 'SHARING_VIA_E_MAIL__C', 'SHARING_VIA_FACEBOOK_BUSINESS__C', 'SHARING_VIA_FACEBOOK__C', 'SHARING_VIA_LINKEDIN__C', 'SHARING_VIA_TWITTER__C', 'UNIQUE_CONTACT_ROLE__C', 'BROKER_DEALER_STATUS__C', 'BROKER_DEALER_ID__C', 'CONTRACT_SIGNED_DATE__C', 'LEVEL_OF_SALES_SUPPORT_AFMO__C', 'REIMBURSEMENT_TYPE__C', 'MARKETING_CREDIT_REDEMPTION_PROCESS__C', 'STAFF_OR_WHOLESALER_EMAIL__C', 'AML_REQUIRED__C', 'AML_TAKEN__C', 'AML_VENDOR__C', 'DATE_COMPLIANCE_TRAINING_TAKEN__C', 'COMPLI ...
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
[i for i in list(sf_contact_df) if 'DATE' in i]
# Out:
# ['CREATEDDATE',
#  'LASTMODIFIEDDATE',
#  'LASTACTIVITYDATE',
#  'LASTCUREQUESTDATE',
#  'LASTCUUPDATEDATE',
#  'LASTVIEWEDDATE',
#  'LASTREFERENCEDDATE',
#  'EMAILBOUNCEDDATE',
#  'DRAW_END_DATE__C',
#  'END_DATE__C',
#  'GOLDMINE_CREATED_DATE__C',
#  'GOLDMINE_LAST_MODIFIED_DATE__C',
#  'START_DATE__C',
#  'CONVERSION_PROGRAM_DATE__C',
#  'FIRST_APPOINTMENT_DATE__C',
#  'BDACTIVEDATE__C',
#  'APPIRIO_CORE__LAST_ACCESS_DATE__C',
#  'WV_CARRIER_UPDATE_EMAILS__C',
#  'AFMO_AGENCY_CARRIER_UPDATE_EMAILS__C',
#  'CONTRACT_SIGNED_DATE__C',
#  'DATE_COMPLIANCE_TRAINING_TAKEN__C',
#  'DATE_LAPSED__C',
#  'CANSELL_DATE__C',
#  'DATE_LICENSE_EXPECTED__C',
#  'MKTO71_ACQUISITION_DATE__C',
#  'FIRST_APPLICATION_DATE__C',
#  'CARRIER_UPDATE_SUB_ELIGIBLE_MARKETO__C',
#  'NEWS_UPDATES_OPTIN_MARKETO__C',
#  'DNC_EXPIRATION_DATE__C',
#  'LAST_INTERESTING_MOMENT_DATE_MARKETO__C',
#  'MKTO_SI__HIDEDATE__C',
#  'MKTO_SI__LAST_INTERESTING_MOMENT_DATE__C',
#  'LAST_CREATED_APPOINTMENT_DATE__C',
#  'MARKETING_T_C_SENT_DATETIME__C',
#  'UPDATE_DETAILS__C',
#  'UPDATE_IMPACT_CURRENT_CASES__C',
#  'DATE_APPROVED_ALLIANZ_IC_WHOLESALER__C',
#  'DATE_LAST_PROGRAM_SUCCESS__C',
#  'LAST_INFOSEC_DATE__C',
#  'BIRTHDATE_MM_DD__C']

# %%
sf_contact_df['LASTACTIVITYDATE'] = pd.to_datetime(sf_contact_df['LASTACTIVITYDATE'])
sf_contact_df.index = sf_contact_df['LASTACTIVITYDATE']

# %%
def fieldsByThreshold(df,up_percent, low_percent=0):
    #percentage of the fields usage in SF
    total_usage_per_col = df.count()/len(df);
    return total_usage_per_col[ total_usage_per_col.between(low_percent/100,up_percent/100)]

# %%
#dict of sf contacts by record type
sf_contact_by_type = {i : sf_contact_df[sf_contact_df['RECORD_TYPE_NAME__C'] == i] for i in sf_contact_df.RECORD_TYPE_NAME__C.unique()}

#fields usage per record type 
usage_map={i: fieldsByThreshold(sf_contact_by_type[i], 101) for i in sf_contact_df.RECORD_TYPE_NAME__C.unique()}
usage_df = pd.DataFrame(usage_map);

# %%
def threshold_per_type(max_threshold, min_num_types): #input a percent, and a minimun number of records types to be under used by
    all_fields  = list(usage_df.index)
    
    fields = [i for i in all_fields if len( [ j for j in list(usage_df.loc[i] <= max_threshold/100) if j==True]) >= min_num_types]            
    return usage_df.loc[fields] #all the fields that fall under 'threshold' usage 'cnt' times
# example -> threshold_per_type(1,12)  all fields that have under 1% usage for 12 or more record types

# %%
def contact_type_using_field(record_type, field_name):
    if record_type =='All':
        contacts = sf_contact_df 
    else:
        contacts = sf_contact_by_type[record_type]
        
    return contacts[contacts[field_name].notnull()]

# %%
#get contacts using under used fields
def contacts_using_fields_in_criteria(thresh_percent, num_types):
    types = list(usage_df.columns)
    types.append('All')
    #fields that fit the criteria
    fields_in_threshold = list(threshold_per_type(thresh_percent, num_types).index)
    #dictionary containing each field in the criteria and the contacts using that field for each record type
    return {i:  {j: contact_type_using_field(j, i) for j in types} for i in fields_in_threshold}

# %%
def date_range_of_contacts(df):
    earliest = df.resample('M').count()[:1].index.date[0].isoformat()
    latest = df.resample('M').count()[-1:].index.date[0].isoformat()
    return f'from {earliest} to {latest}'

# %%
# usage_df[usage_df.apply(np.max, axis=1) < 0.1]  #all fields whos max usage is below 1%

# %%
list(usage_df.columns)
# Out:
# ['Wholesaler Contact Record Type',
#  'Business Contact Record Type',
#  'Wealthvest Staff Record Type',
#  'Contracted Producer Contact',
#  'Producer Contact Record Type',
#  'AFMO Contact Record Type',
#  'Agency Contact Record Type',
#  'Private Business Contact Record Type',
#  'Private Operations Business Contact Record Type',
#  'Vendor Contact Record Type',
#  'FinancialForce Contact Record Type',
#  'Public Business Contact Record Type']

# %%
contact_type_using_field('All','ADDITIONAL_FAX__C')
# Out:
#                                   ID  ISDELETED  MASTERRECORDID  \
# LASTACTIVITYDATE
# 2018-08-09        0033600001WS7zQAAT      False             NaN
#
#                            ACCOUNTID  LASTNAME FIRSTNAME SALUTATION  \
# LASTACTIVITYDATE
# 2018-08-09        0013600001PHzpKAAT  Business       New        NaN
#
#                  MIDDLENAME SUFFIX          NAME  \
# LASTACTIVITYDATE
# 2018-08-09              NaN    NaN  New Business
#
#                                         ...                          \
# LASTACTIVITYDATE                        ...
# 2018-08-09                              ...
#
#                  ZZJEF_TEMP4__C MARKETO_ACCESS__C DEAL_SYSTEM_ACCESS__C  \
# LASTACTIVITYDATE
# 2018-08-09                  NaN             False                 False
#
#                  COMMISSION_SYSTEM_ACCESS__C BIRTHDATE_MM_DD__C TITLE__C  \
# LASTACTIVITYDATE
# 2018-08-09                             False                NaN      NaN
#
#                   DEPARTMENT__C  MARKETING_EMAIL_ALIAS_KEY__C  \
# LASTACTIVITYDATE
# 2018-08-09                  NaN                        kfauls
#
#                   MARKETO_PROFILE_PICTURE_URL__C  \
# LASTACTIVITYDATE
# 2018-08-09                                   NaN
#
#                                                    RECORD_STATUS__C
# LASTACTIVITYDATE
# 2018-08-09        <img src="/servlet/servlet.FileDownload?file= ...
#
# [1 rows x 531 columns]

# %%
x= contacts_using_fields_in_criteria(0,12)

# %%
zero_usage_field = sorted(list(x.keys()))

# %%
from selenium import webdriver
browser = webdriver.Chrome()

# %%
browser.get('https://na30.salesforce.com/p/setup/layout/LayoutFieldList?type=Contact&setupid=ContactFields')

# %%
api_selector= '#CustomFieldRelatedList_body > table > tbody > tr.dataRow > td:nth-child(4)'
d_type_selector = '#CustomFieldRelatedList_body > table > tbody > tr.dataRow > td:nth-child(6)'
api_2_type_map = {i.text.upper(): j.text for i,j in zip(browser.find_elements_by_css_selector(api_selector),browser.find_elements_by_css_selector(d_type_selector))}

# %%
api_2_type_map
# Out:
# {'RECORD_STATUS__C': 'Formula (Text)',
#  'X84_24_ASSISTANCE_NEEDED__C': 'Picklist',
#  'A_P_ACCOUNT__C': 'Lookup(Account)',
#  'ACCOUNT_ID__C': 'Formula (Text)',
#  'ACCOUNT_ID_STRING__C': 'Text(100)',
#  'ACCOUNT_TEXT__C': 'Text(100)',
#  'MKTO71_ACQUISITION_DATE__C': 'Date/Time',
#  'MKTO71_ACQUISITION_PROGRAM__C': 'Text(255)',
#  'MKTO71_ACQUISITION_PROGRAM_ID__C': 'Number(18, 0)',
#  'ACQUISITION_STAGE__C': 'Picklist',
#  'PSE__ACTION_CALCULATE_UTILIZATION__C': 'Checkbox',
#  'PSE__ACTION_UPDATE_CURRENT_TIME_PERIOD__C': 'Checkbox',
#  'ACTIVE_STAFF__C': 'Formula (Checkbox)',
#  'ACTIVE_TERRITORY__C': 'Formula (Text)',
#  'ACTIVE_USER__C': 'Formula (Checkbox)',
#  'ACTIVE_WHOLESALER__C': 'Formula (Checkbox)',
#  'ACTIVE_WITH_GAINFULLY__C': 'Checkbox',
#  'PSE__ACTUALS_LAST_UPDATE_DATE__C': 'Date/Time',
#  'PSE__ACTUALS_LAST_UPDATED_BY__C': 'Lookup(User)',
#  'ADDITIONAL_BANK_RULE_INDICATOR__C': 'Formula (Checkbox)',
#  'ADDITIONAL_BANK_RULES__C': 'Long Text Area(32768)',
#  'ADDITIONAL_CONTACTS__C': 'Lookup(Case)',
#  'ADDITIONAL_FAX__C': 'Phone',
#  'ADDRESS_TYPE__C': 'Picklist',
#  'ADDRESS_TYPE_2__C': 'Picklist',
#  'MKTO_SI__ADD_TO_MARKETO_CAMPAIGN__C': 'Formula (Text)',
#  'ADVISORY__C': 'Percent(18, 0)',
#  'AFFILIATION_CHANGE_EMAIL_SENT__C': 'Checkbox',
#  'AFMO_ACCOUNT__C': 'Lookup(Account)',
#  'AFMO_AGENCY_CARRIER_UPDATE_EMAILS__C': 'Formula (Text)',
#  'AFMO_RECRUITER__C': 'Formula (Text)',
#  'AGENCY__C': 'Lookup(Account)',
#  'AGENCY_NAME_MARKETO__C': 'Formula (Text)',
#  'AGGREGATE_FIRM__C': 'Formula (Text)',
#  'ALLIANZ_APPROVED_IC_WHOLESALER__C': 'Picklist',
#  'ALLIANZ_BDMA_FIRM__C': 'Formula (Checkbox)',
#  'ALLIANZ_PREFERRED_MARKETING_PROGRAM__C': 'Roll-Up Summary (COUNT Producer Marketing Program)',
#  'PSE__ALLOW_TIMECARDS_WITHOUT_ASSIGNMENT__C': 'Checkbox',
#  'ALL_WV_MARKETING_MATERIALS_APPROVED_AFMO__C': 'Formula (Checkbox)',
#  'ALL_WV_MARKETING_MATERIALS_APPROVED__C': 'Formula (Checkbox)',
#  'ALTERNATIVE_INVESTMENTS__C': 'Percent(18, 0)',
#  'ALT_SOURCE__C': 'Text(200)',
#  'ALT_SOURCE_2__C': 'Text(50)',
#  'AML_EXPIRATION__C': 'Formula (Date)',
#  'AML_REQUIRED__C': 'Picklist',
#  'AML_TAKEN__C': 'Date',
#  'AML_VENDOR__C': 'Picklist',
#  'ANNUAL_FIXED_ANNUITY_PRODUCTION__C': 'Picklist',
#  'ANNUAL_GD__C': 'Picklist',
#  'ANNUAL_VARIABLE_ANNUITY_PRODUCTION__C': 'Picklist',
#  'ANNUITY_ABC__C': 'Picklist',
#  'ANNUITY_TOTAL__C': 'Percent(18, 0)',
#  'APPLICATION_MANAGER_TOBE__C': 'Lookup(User)',
#  'APPLYNOW_PERMITTED__C': 'Formula (Checkbox)',
#  'APPROVED_APPOINTMENT_COUNT__C': 'Roll-Up Summary (COUNT Carrier Appointment)',
#  'APPROVED_MARKETING_MATERIAL_NOTES_AFMO__C': 'Long Text Area(32768)',
#  'APPROVED_PRODUCT_LIST_AVAILABLE__C': 'Formula (Checkbox)',
#  'APPROVED_PRODUCT_LIST_AVAILABLE_AFMO__C': 'Formula (Checkbox)',
#  'APPROVED_SALES_CHANNELS__C': 'Formula (Text)',
#  'APPROVED_SALES_CHANNELS_AFMO__C': 'Formula (Text)',
#  'AREA__C': 'Number(3, 0)',
#  'ASSETS_UNDER_MANAGEMENT__C': 'Currency(18, 0)',
#  'ASSETS_UNDER_MANAGMENT__C': 'Formula (Currency)',
#  'ASSISTANT_S_EMAIL__C': 'Email',
#  'AUM_IN_CASH__C': 'Percent(18, 0)',
#  'AVERAGE_FIA_PRODUCTION__C': 'Picklist',
#  'AVERAGE_PRODUCTION_REP__C': 'Formula (Currency)',
#  'BACKGROUND_RUN__C': 'Picklist',
#  'BANK__C': 'Text(200)',
#  'BANK_BD_PERMITED_TACTICS_DELTA__C': 'Long Text Area(32768)',
#  'BASE_SALESFORCE_PROFILE__C': 'Picklist',
#  'BDACTIVEDATE__C': 'Date',
#  'BD_AGGREGATE_FIRM__C': 'Formula (Text)',
#  'BD_APPROVED_MARKETING_MATERIAL_NOTES__C': 'Long Text Area(32768)',
#  'BD_NAME_MARKETO__C': 'Formula (Text)',
#  'BD_ORGANIZATION__C': 'Text(255)',
#  'BD_PERMITTED_TACTICS_NOTES__C': 'Long Text Area(32768)',
#  'BD_ROLE__C': 'Text(100)',
#  'BEHAVIOR_SCORE_MARKETO__C': 'Number(10, 0)',
#  'PSE__BILLABLE_EXTERNAL_HOURS__C': 'Number(16, 2)',
#  'PSE__BILLABLE_INTERNAL_HOURS__C': 'Number(16, 2)',
#  'PSE__BILLED__C': 'Currency(16, 2)',
#  'PSE__BILLINGS__C': 'Currency(16, 2)',
#  'BIRTHDATE_MM_DD__C': 'Formula (Text)',
#  'BIRTHDAY_MM_DD__C': 'Text(5)',
#  'BOA_BRANCH_OFFICE_ADMINISTRATOR__C': 'Text(255)',
#  'PSE__BOOKINGS__C': 'Currency(16, 2)',
#  'BRANCH__C': 'Text(255)',
#  'BRANCH_MANAGER__C': 'Text(255)',
#  'BROKER_CHECK__C': 'Checkbox',
#  'BROKER_DEALER__C': 'Lookup(Account)',
#  'BROKER_DEALER_ID__C': 'Formula (Text)',
#  'BROKER_DEALER_STATUS__C': 'Formula (Text)',
#  'BROKER_DEALER_TEXT__C': 'Text(100)',
#  'BUSINESS_INTERESTS__C': 'Picklist (Multi-Select)',
#  'CANSELL_DATE__C': 'Date',
#  'CAREERS_OPTIN_MARKETO__C': 'Checkbox',
#  'CARRIER_RATE_SPLS_SUB_ELIGIBLE_MARKETO__C': 'Checkbox',
#  'CARRIER_TRIPS_ALLOWED__C': 'Formula (Checkbox)',
#  'CARRIER_UPDATE_SUB_ELIGIBLE_MARKETO__C': 'Checkbox',
#  'CC_CONFIRMED_BY_PRODUCER__C': 'Checkbox',
#  'CC_IPL_INITIAL_UPLOAD__C': 'Checkbox',
#  'CC_ON_CONTRACTING_EMAILS__C': 'Checkbox',
#  'CC_PRODUCER_CONFIRMATION_COUNT__C': 'Number(2, 0)',
#  'CC_CONFIRMATION_EMAIL__C': 'Formula (Text)',
#  'CC_EMAIL_1__C': 'Email',
#  'CC_EMAIL_2__C': 'Email',
#  'CC_EMAIL_3__C': 'Email',
#  'CC_EMAIL_4__C': 'Email',
#  'CC_NAME_1__C': 'Text Area(255)',
#  'CC_NAME_2__C': 'Text Area(255)',
#  'CC_NAME_3__C': 'Text Area(255)',
#  'CC_NAME_4__C': 'Text Area(255)',
#  'CERT_FOR_PROTECTING_CONFIDENTIAL_INFO__C': 'Picklist',
#  'CHANNEL__C': 'Picklist',
#  'COACHING_OPTIN_MARKETO__C': 'Checkbox',
#  'COLORADO_BANKERS_SUB_ELIGIBLE_MARKETO__C': 'Checkbox',
#  'COMINGLING_WEBINARS__C': 'Formula (Checkbox)',
#  'COMMENT_CAPTURE_MARKETO__C': 'Long Text Area(30000)',
#  'COMMENT_HISTORY_MARKETO__C': 'Long Text Area(30000)',
#  'COMMISSIONS_CAN_BE_DISCUSSED__C': 'Formula (Text)',
#  'COMMISSION_SYSTEM_ACCESS__C': 'Checkbox',
#  'COMPANY__C': 'Text(255)',
#  'COMPANY_NOTES_MARKETO__C': 'Long Text Area(30000)',
#  'COMPLIANCE_ACKNOWLEDGEMENT_CERTIFICATE__C': 'Picklist',
#  'COMPLIANCE_APPROVAL__C': 'Formula (Checkbox)',
#  'COMPLIANCE_APPROVAL_AFMO__C': 'Formula (Checkbox)',
#  'COMPUTER_NAME__C': 'Text(30) (Unique Case Insensitive)',
#  'CONFERENCE_TRACKING__C': 'Text Area(255)',
#  'CONTACT_AFMO__C': 'Formula (Text)',
#  'CONTACT_NAME__C': 'Formula (Text)',
#  'CONTACT_STAGE__C': 'Picklist',
#  'CONTACT_STATUS__C': 'Picklist',
#  'CONTACT_TYPE__C': 'Picklist',
#  'CONTRACT_COC__C': 'Text(4)',
#  'CONTRACT_DATE_OF_BIRTH_MM_DD__C': 'Formula (Text)',
#  'CONTRACTING_WHOLESALER__C': 'Text(50)',
#  'CONTRACT_SIGNED_DATE__C': 'Date',
#  'CONVERSION_PROGRAM__C': 'Text(255)',
#  'CONVERSION_PROGRAM_DATE__C': 'Date',
#  'COUNTY__C': 'Text(100)',
#  'CRD__C': 'Text(15) (External ID)',
#  'ECONTACTS__CREATED_BY_ECONTACTS__C': 'Checkbox',
#  'PSE__CREDITED_NON_BILLABLE_INTERNAL_HOURS__C': 'Number(16, 2)',
#  'CRITICAL_PERSONNEL__C': 'Checkbox',
#  'CURRENT_BOOK_SIZE_OF_AGENTS__C': 'Number(5, 0)',
#  'CURRENT_FMO__C': 'Picklist',
#  'CURRENTLY_EMPLOYEED__C': 'Checkbox',
#  'PSE__CURRENT_TIME_PERIOD__C': 'Lookup(Time Period)',
#  'PSE__CURRENT_TIME_PERIOD_END_DATE__C': 'Date',
#  'DATE_APPROVED_ALLIANZ_IC_WHOLESALER__C': 'Date',
#  'DATE_COMPLIANCE_TRAINING_TAKEN__C': 'Date',
#  'DATE_LAPSED__C': 'Date',
#  'DATE_LICENSE_EXPECTED__C': 'Date',
#  'DEAL_SYSTEM_ACCESS__C': 'Checkbox',
#  'PSE__DEFAULT_COST_RATE__C': 'Currency(16, 2)',
#  'PSE__DAILY_DEFAULT_COST_RATE__C': 'Checkbox',
#  'D_LIFE_SUB_ELIGIBLE_MARKETO__C': 'Checkbox',
#  'RESIDENT_LICENSE_STATE__C': 'Picklist',
#  'RESIDENT_LICENSE__C': 'Text(25)',
#  'DEMOGRAPHIC_SCORE_MARKETO__C': 'Number(10, 0)',
#  'DEPARTMENT_MARKETO__C': 'Text(255)',
#  'DEPARTMENT__C': 'Picklist',
#  'DIRECT_CONTACT_WITH_AGENT_AGENCY_AFMO__C': 'Formula (Text)',
#  'DIRECT_CONTACT_WITH_AGENT_BD__C': 'Formula (Text)',
#  'DIRECT_PARTICIPATION_PROGRAM__C': 'Percent(18, 0)',
#  'DNC_AGREEMENT_NAME__C': 'Text(50)',
#  'DNC_EXPIRATION_DATE__C': 'Date',
#  'DOES_RECRUIT_HAVE_INSURANCE_LICENSE__C': 'Checkbox',
#  'DOING_BUSINESS_AS__C': 'Text(100)',
#  'DOL_COMPLIANCE_TRAINING__C': 'Date',
#  'DOL_NOTICE__C': 'Checkbox',
#  'DO_NOT_CALL_CAUSE_MARKETO__C': 'Text Area(255)',
#  'DO_NOT_CALL_REASON_MARKETO__C': 'Text Area(255)',
#  'DO_NOT_CONTACT_UNTIL__C': 'Date',
#  'DRAW_AMOUNT__C': 'Currency(6, 0)',
#  'DRAW_END_DATE__C': 'Date',
#  'DUE_DILIGENCE_TIPS_ALLOWED__C': 'Formula (Checkbox)',
#  'DUE_DILIGENCE_TIPS_ALLOWED_AFMO__C': 'Formula (Checkbox)',
#  'CURRENT_YEAR_PAID_PREMIUM__C': 'Roll-Up Summary (SUM Producer Application Line Item)',
#  'CURRENT_YEAR_SUBMITTED_PREMIUM__C': 'Roll-Up Summary (SUM Producer Application Line Item)',
#  'E_O_COVERAGE_LIMITS__C': 'Picklist',
#  'E_O_EXPIRATION__C': 'Date',
#  'E_O_REQUIRED__C': 'Picklist',
#  'E_O_VENDOR__C': 'Text(55)',
#  'EAGLE_LIFE_SUB_ELIGIBLE_MARKETO__C': 'Checkbox',
#  'EIN__C': 'Text(10)',
#  'EIN_LAST_4__C': 'Formula (Text)',
#  'ELITE_PRODUCER_CLUB__C': 'Checkbox',
#  'ELITE_PRODUCER_CLUB_QUALIFICATION__C': 'Number(18, 0)',
#  'ELITE_PRODUCER_TRIPS_ALLOWED__C': 'Formula (Checkbox)',
#  'ELITE_PRODUCER_TRIPS_ALLOWED_AFMO__C': 'Formula (Checkbox)',
#  'ELITE_PRODUCER_UNTIL__C': 'Date',
#  'EMAIL_AUTHORIZATION__C': 'Checkbox',
#  'EMAIL_INVALID_MARKETO__C': 'Checkbox',
#  'EMAIL_INVALID_CAUSE_MARKETO__C': 'Text Area(255)',
#  'EMPLOYEE_BIO__C': 'Picklist',
#  'EMPLOYEE_HEADSHOT__C': 'Picklist',
#  'C2G__ENABLEEMAILNOTIFICATION__C': 'Checkbox',
#  'END_DATE__C': 'Date',
#  'ENDORSED_AS_OFFICAL_SOLUTION_AFMO__C': 'Formula (Checkbox)',
#  'ENDORSED_AS_OFFICIAL_SOLUTION__C': 'Formula (Checkbox)',
#  'ENGAGEMENT_MARKETO__C': 'Number(18, 0)',
#  'MKTO_SI__PRIORITY__C': 'Number(18, 0)',
#  'EQUITY_INDEX_ANNUITY__C': 'Percent(18, 0)',
#  'PSE__ERP_WORKER_CORRELATION_ID__C': 'Text(255) (External ID)',
#  'PSE__EXCLUDED_HOURS__C': 'Number(16, 2)',
#  'PSE__EXCLUDE_FROM_MISSING_TIMECARDS__C': 'Checkbox',
#  'PSE__EXCLUDE_FROM_RESOURCE_PLANNER__C': 'Checkbox',
#  'PSE__EXCLUDE_FROM_TIME_CALCULATIONS__C': 'Checkbox',
#  'PSE__EXCLUDE_FROM_TIME_VARIANCE__C': 'Checkbox',
#  'EXPECTED_TO_TRANSFER_30DAYS__C': 'Number(5, 0)',
#  'EXPECTED_TO_TRANSFER_60DAYS__C': 'Number(5, 0)',
#  'PSE__EXPENSE_BUDGET__C': 'Currency(16, 2)',
#  'PSE__EXPENSE_COSTS__C': 'Currency(16, 2)',
#  'COST_CENTER__C': 'Picklist',
#  'FFPSAI__EXPENSEREIMBURSEMENTACCOUNT__C': 'Lookup(Account)',
#  'PSE__EXTERNAL_COSTS__C': 'Currency(16, 2)',
#  'PSE__EXTERNAL_RESOURCE__C': 'Checkbox',
#  'FIA_MARKETING_OPTIN_MARKETO__C': 'Checkbox',
#  'FIELD_TRAINER_LEADER__C': 'Checkbox',
#  'FINANCIAL_INSTITUTION__C': 'Lookup(Account)',
#  'OTHER_FINANCIAL_INSTITUTION__C': 'Text(75)',
#  'FINANCIAL_PLANNING_TOOLS__C': 'Picklist (Multi-Select)',
#  'FINRA_BROKERCHECK__C': 'Formula (Text)',
#  'FIRST_APPLICATION_DATE__C': 'Roll-Up Summary (MIN Producer Application Line Item)',
#  'FIRST_APPOINTMENT_DATE__C': 'Roll-Up Summary (MIN Carrier Appointment)',
#  'FIRST_CONVERSION_PROGRAM__C': 'Checkbox',
#  'FIRST_MARKED_ACTIVE_WITH_GAINFULLY_DATE__C': 'Date',
#  'FIXED_ANNUITY__C': 'Formula (Currency)',
#  'FIXED_ANNUITYBA__C': 'Percent(18, 0)',
#  'FIXED_INCOME__C': 'Percent(18, 0)',
#  'FIXED_INDEX_ANNUITY__C': 'Formula (Currency)',
#  'FIXED_MARKETING_OPTIN_MARKETO__C': 'Checkbox',
#  'GAINFULLY_OPTIN_MARKETO__C': 'Checkbox',
#  'GAINFULLY_SUBSCRIPTION_ELIGIBLE_MARKETO__C': 'Checkbox',
#  'GDC__C': 'Text(50)',
#  'GENDER__C': 'Picklist',
#  'GENDER_HR__C': 'Picklist',
#  'GENERAL_SECURITY__C': 'Percent(18, 0)',
#  'GIFTS_YTD__C': 'Currency(8, 2)',
#  'GOLDMINE_CREATED_DATE__C': 'Date/Time',
#  'GOLDMINE_ID__C': 'Text(50) (External ID)',
#  'GOLDMINE_LAST_MODIFIED_DATE__C': 'Date/Time',
#  'PSE__GROUP__C': 'Lookup(Group)',
#  'GROUP_ANNUITY__C': 'Percent(18, 0)',
#  'HARD_COPY_MAILING_ALLOWED_AFMO__C': 'Formula (Checkbox)',
#  'HARD_COPY_MAILING_ALLOWED__C': 'Formula (Checkbox)',
#  'HAS_AGENT_LIST__C': 'Checkbox',
#  'MKTO_SI__HIDEDATE__C': 'Date',
#  'PSE__HISTORICAL_UTILIZATION__C': 'Percent(8, 2)',
#  'PSE__HISTORICAL_UTILIZATION_BILLABLE_HOURS__C': 'Number(16, 2)',
#  'PSE__HISTORICAL_UTILIZATION_CALENDAR_HOURS__C': 'Number(16, 2)',
#  'PSE__HISTORICAL_UTILIZATION_CREDITED_HOURS__C': 'Number(16, 2)',
#  'PSE__HISTORICAL_UTILIZATION_EXCLUDED_HOURS__C': 'Number(16, 2)',
#  'PSE__HISTORICAL_UTILIZATION_NON_BILLABLE_HRS__C': 'Number(16, 2)',
#  'PSE__HISTORICAL_UTILIZATION_TARGET__C': 'Formula (Percent)',
#  'PSE__HISTORICAL_UTILIZATION_TARGET_ATTAINMENT__C': 'Formula (Percent)',
#  'PSE__HISTORICAL_UTILIZATION_TARGET_HOURS__C': 'Number(16, 2)',
#  'PSA_REPORT__HIST_SCH_UTILIZATION__C': 'Formula (Percent)',
#  'PSE__HIST_SCH_UTILIZATION_BILLABLE_HOURS__C': 'Number(16, 2)',
#  'PSE__HIST_SCH_UTILIZATION_CREDITED_HOURS__C': 'Number(16, 2)',
#  'PSE__HIST_SCH_UTILIZATION_EXCLUDED_HOURS__C': 'Number(16, 2)',
#  'PSE__HIST_SCH_UTILIZATION_HELD_HOURS__C': 'Number(16, 2)',
#  'PSE__HIST_SCH_UTILIZATION_NON_BILLABLE_HRS__C': 'Number(16, 2)',
#  'HOME_PHONE_HR__C': 'Phone',
#  'HYBRID_WHOLESALER__C': 'Checkbox',
#  'IF_EMPLOYED_WITH_WHOM__C': 'Text(80)',
#  'ECONTACTS__BUSINESS_CARD__C': 'Long Text Area(131072)',
#  'INSURANCE__C': 'Percent(18, 0)',
#  'PSE__INTERNAL_BUDGET__C': 'Currency(16, 2)',
#  'PSE__INTERNAL_COSTS__C': 'Currency(16, 2)',
#  'INTERNAL_WHOLESALER__C': 'Formula (Text)',
#  'INTERNAL_WHOLESALER_TOBE__C': 'Lookup(User)',
#  'PSE__INVOICED__C': 'Currency(16, 2)',
#  'IP_ADDRESS_MARKETO__C': 'Text Area(255)',
#  'IPIPELINE_ID__C': 'Text(25) (External ID)',
#  'IPIPEOWNERID__C': 'Formula (Text)',
#  'IS_CUSTOMER_MARKETO__C': 'Checkbox',
#  'IS_OSJ__C': 'Checkbox',
#  'IS_PARTNER_MARKETO__C': 'Checkbox',
#  'PSE__IS_RESOURCE__C': 'Checkbox',
#  'PSE__IS_RESOURCE_ACTIVE__C': 'Checkbox',
#  'IT_IDENTIFY_HIDDEN__C': 'Text(255)',
#  'KEY_RESPONSIBILITIES__C': 'Long Text Area(50000)',
#  'PSE__LANGUAGES__C': 'Text(100)',
#  'APPIRIO_CORE__LAST_ACCESS_DATE__C': 'Date/Time',
#  'LAST_APPLICATION_DATE__C': 'Roll-Up Summary (MAX Producer Application Line Item)',
#  'LAST_CREATED_APPOINTMENT_DATE__C': 'Roll-Up Summary (MAX Carrier Appointment)',
#  'PSE__LAST_DATE__C': 'Date',
#  'LAST_INFOSEC_DATE__C': 'Date',
#  'MKTO_SI__LAST_INTERESTING_MOMENT__C': 'Formula (Text)',
#  'LAST_INTERESTING_MOMENT_DATE_MARKETO__C': 'Date/Time',
#  'MKTO_SI__LAST_INTERESTING_MOMENT_DATE__C': 'Date/Time',
#  'LAST_INTERESTING_MOMENT_DESC_MARKETO__C': 'Long Text Area(30000)',
#  'MKTO_SI__LAST_INTERESTING_MOMENT_DESC__C': 'Text Area(255)',
#  'LAST_INTERESTING_MOMENT_SOURCE_MARKETO__C': 'Text Area(255)',
#  'MKTO_SI__LAST_INTERESTING_MOMENT_SOURCE__C': 'Text(100)',
#  'LAST_INTERESTING_MOMENT_TYPE_MARKETO__C': 'Text Area(255)',
#  'MKTO_SI__LAST_INTERESTING_MOMENT_TYPE__C': 'Text(100)',
#  'LAST_MARKED_ACTIVE_WITH_GAINFULLY_DATE__C': 'Date',
#  'LAST_PROGRAM_SUCCESS_MARKETO__C': 'Text Area(255)',
#  'DATE_LAST_PROGRAM_SUCCESS__C': 'Date',
#  'LAST_YEARS_PRODUCTION__C': 'Currency(18, 0)',
#  'PSE__LATITUDE_PSA__C': 'Number(2, 8)',
#  'LEAD_ESSENTIALS_SUB_ELIGIBLE_MARKETO__C': 'Checkbox',
#  'LEAD_OWNER_ID_MARKETO__C': 'Text Area(255)',
#  'LEGAL_FIRST_NAME__C': 'Text(25)',
#  'LEGAL_LAST_NAME__C': 'Text(35)',
#  'LEGAL_MIDDLE_INITIAL__C': 'Text(1)',
#  'PSE__LEVEL__C': 'Picklist',
#  'LEVEL_GROUP__C': 'Picklist',
#  'LEVEL_LEADER__C': 'Picklist (Multi-Select)',
#  'LEVEL_OF_SALES_SUPPORT_AFMO__C': 'Formula (Text)',
#  'APPIRIO_CORE__LICENSED_FEATURES__C': 'Picklist (Multi-Select)',
#  'LICENSE_EXPIRATION__C': 'Text(35)',
#  'LICENSE_RESIDENT_STATE__C': 'Picklist',
#  'LIFECYCLE_STATUS_MARKETO__C': 'Text Area(255)',
#  'LIST_SOURCE__C': 'Text(100)',
#  'LLC_CORPORATION_IN_PLACE__C': 'Checkbox',
#  'LLC_CORPORATION_NAME__C': 'Text(100)',
#  'ECONTACTS__LOCATION__C': 'Geolocation',
#  'ECONTACTS__LOCATION_TEXT__C': 'Text(255)',
#  'PSE__LONGITUDE_PSA__C': 'Number(3, 8)',
#  'MAILING_CITY_HR__C': 'Text Area(255)',
#  'MAILING_STATE_HR__C': 'Text(2)',
#  'MAILING_STREET_HR__C': 'Long Text Area(500)',
#  'MAILING_ZIP_POSTAL_CODE_HR__C': 'Text(5)',
#  'PSE__MARGIN__C': 'Formula (Currency)',
#  'MARKETING_CAMPAIGNS__C': 'Picklist (Multi-Select)',
#  'MARKETING_CREDIT_REDEMPTION_PROCESS__C': 'Formula (Text)',
#  'MARKETING_CREDITS_CONTRACT_OVERRIDE__C': 'Lookup(Contract)',
#  'MARKETING_EMAIL_ALIAS_KEY__C': 'Formula (Text)',
#  'MARKETING_SUSPENDED__C': 'Checkbox',
#  'MARKETING_T_C_SENT__C': 'Checkbox',
#  'MARKETING_T_C_SENT_DATETIME__C': 'Date/Time',
#  'MARKETING_T_C_SENT_MARKETING_PROGRAM__C': 'Lookup(Marketing Program)',
#  'MARKETING_TO_UNAPPOINTED_PRODUCERS__C': 'Formula (Checkbox)',
#  'MARKETO_ACCESS__C': 'Checkbox',
#  'MARKETO_PROFILE_PICTURE_URL__C': 'URL(255)',
#  'MARKETO_SYNC_USER__C': 'Checkbox',
#  'MARKET_SOURCES__C': 'Picklist (Multi-Select)',
#  'MASSMUTUAL_SUBSCRIPTION_ELIGIBLE__C': 'Checkbox',
#  'MASTERMIND_SUBSCRIPTION_ELIGIBLE_MARKETO__C': 'Checkbox',
#  'MEMO_EMAIL__C': 'Email',
#  'MFA_ENABLED__C': 'Checkbox',
#  'MIDDLE_NAME__C': 'Text(50)',
#  'MIGRATED__C': 'Checkbox',
#  'MKTO_SI__MKTO_LEAD_SCORE__C': 'Number(18, 0)',
#  'MSA__C': 'Lookup(Account)',
#  'MULTIPLE_WHOLESALER__C': 'Checkbox',
#  'MUTUAL_FUND__C': 'Percent(18, 0)',
#  'MYGA_AS_OBA__C': 'Formula (Checkbox)',
#  'MYGA_AS_OBA_NOTES__C': 'Formula (Text)',
#  'MY_SEGMENT__C': 'Lookup(MySegment)',
#  'NAME__C': 'Text(50)',
#  'NATIONAL_PRODUCER_NUMBER_MARKETO__C': 'Number(18, 0)',
#  'NATIONAL_SALES_MANAGER__C': 'Lookup(User)',
#  'NEWS_UPDATES_OPTIN_MARKETO__C': 'Checkbox',
#  'NICKNAME__C': 'Text(50)',
#  'NO_MASS_E_MAIL_CAMPAIGNS_AFMO__C': 'Formula (Checkbox)',
#  'NO_MASS_E_MAIL_CAMPAIGNS__C': 'Formula (Checkbox)',
#  'PSE__NON_BILLABLE_EXTERNAL_HOURS__C': 'Number(16, 2)',
#  'PSE__NON_BILLABLE_INTERNAL_HOURS__C': 'Number(16, 2)',
#  'NON_CASH_REIMBURSEMENTS__C': 'Formula (Checkbox)',
#  'NON_COMPETE__C': 'Checkbox',
#  'NPN__C': 'Text(55)',
#  'NSM__C': 'Formula (Text)',
#  'NUMBER_OF_REPS_AFMO__C': 'Formula (Number)',
#  'NUMBER_OF_REPS_BD__C': 'Formula (Number)',
#  'OFFICE_EXT__C': 'Text(10)',
#  'OFFICE_LOCATION__C': 'Picklist',
#  'ONBOARDING_NOTES__C': 'Long Text Area(32768)',
#  'ONBOARDING_STATUS__C': 'Picklist',
#  'ONBOARD_STATUS_COMPLETE__C': 'Checkbox',
#  'OPTIONS__C': 'Percent(18, 0)',
#  'ORGANIZATION__C': 'Picklist',
#  'ORGANIZATION_CHANGE_DETAILS__C': 'Long Text Area(32768)',
#  'OTHER__C': 'Percent(18, 0)',
#  'PSE__OTHER_COSTS__C': 'Currency(16, 2)',
#  'OTHER_EMAIL__C': 'Email',
#  'OWNER_ID_STRING__C': 'Text(18)',
#  'OWNER_NAME__C': 'Formula (Text)',
#  'PL__C': 'Formula (Text)',
#  'PSE__PASS_THROUGH_BILLINGS__C': 'Currency(16, 2)',
#  'PENDING_APPOINTMENT_COUNT__C': 'Roll-Up Summary (COUNT Carrier Appointment)',
#  'PERFORMANCE_LEADER__C': 'Checkbox',
#  'PERMITTED__C': 'Formula (Checkbox)',
#  'PERMITTED_AFMO__C': 'Formula (Checkbox)',
#  'PERMITTED_E_APP_PLATFORMS__C': 'Formula (Text)',
#  'PERMITTED_TACTICS_NOTES_AFMO__C': 'Long Text Area(32768)',
#  'PERSONAL_EMAIL__C': 'Email',
#  'PERSONAL_EMAIL_HR__C': 'Email',
#  'PERSON_NOTES_MARKETO__C': 'Long Text Area(35000)',
#  'PERSON_RATING_MARKETO__C': 'Text Area(255)',
#  'PERSON_SCORE_MARKETO__C': 'Number(10, 0)',
#  'PERSON_SOURCE_MARKETO__C': 'Text Area(255)',
#  'PERSON_STATUS_MARKETO__C': 'Text Area(255)',
#  'PHONE_MAC_ADDRESS__C': 'Text(12)',
#  'APPIRIO_CORE__PIN__C': 'Text Area(255)',
#  'PLATFORM_TYPE__C': 'Picklist',
#  'PORTAL_PASSWORD__C': 'Text(50)',
#  'PSE__PRACTICE__C': 'Lookup(Practice)',
#  'PSE__PRE_BILLED__C': 'Currency(16, 2)',
#  'PREFERENCES__C': 'Text Area(255)',
#  'PREFERRED_CONTACT_METHOD__C': 'Picklist',
#  'PREFERRED_CONTACT_METHOD_MARKETO__C': 'Text Area(255)',
#  'PREFERRED_FIRST_NAME__C': 'Text(50)',
#  'PREFERRED_INSURANCE_CARRIERS__C': 'Picklist (Multi-Select)',
#  'PREFERRED_PHONE__C': 'Picklist',
#  'PREFERRED_PRODUCTS__C': 'Picklist (Multi-Select)',
#  'PREVIOUSLY_CONTRACTED__C': 'Checkbox',
#  'PRINCIPAL__C': 'Picklist',
#  'PRIORITY_MARKETO__C': 'Number(18, 0)',
#  'PRODUCER_NAME__C': 'Formula (Text)',
#  'PRODUCER_WEBSITE__C': 'URL(255)',
#  'PRODUCTION_CREDITS__C': 'Formula (Text)',
#  'PRODUCTION_CREDITS_AFMO__C': 'Formula (Text)',
#  'PRODUCTION_TIER__C': 'Picklist',
#  'PROGRAM_MANAGER__C': 'Formula (Text)',
#  'QUALIFIED_BUSINESS_WRITTEN_THROUGH__C': 'Picklist',
#  'RANK__C': 'Text(15)',
#  'RC_EMC_DEAL_OPTIONS__C': 'Picklist',
#  'REASON__C': 'Picklist',
#  'RECORD_TYPE_NAME__C': 'Formula (Text)',
#  'RECORD_TYPE_STRING__C': 'Text(18)',
#  'RECRUITER__C': 'Lookup(User)',
#  'RECRUITER_HR__C': 'Lookup(User)',
#  'RECRUITER_NAME__C': 'Formula (Text)',
#  'REFERRER__C': 'Lookup(User)',
#  'PSE__REGION__C': 'Lookup(Region)',
#  'REGION__C': 'Text(55)',
#  'REGIONAL_LEADER__C': 'Checkbox',
#  'REGISTRATIONS__C': 'Picklist (Multi-Select)',
#  'REIMBURSEMENT_TYPE__C': 'Formula (Text)',
#  'RELATIONSHIP__C': 'Picklist',
#  'RELATIVE_SCORE_MARKETO__C': 'Number(18, 0)',
#  'MKTO_SI__RELATIVE_SCORE__C': 'Formula (Text)',
#  'RELATIVE_SCORE_VALUE_MARKETO__C': 'Number(18, 0)',
#  'MKTO_SI__RELATIVE_SCORE_VALUE__C': 'Number(4, 0)',
#  'RELATIVE_URGENCY_MARKETO__C': 'Number(18, 0)',
#  'REP_CRD_MARKETO__C': 'Number(18, 0)',
#  'REP_LIST_REFRESH__C': 'Formula (Date)',
#  'REPORTING_MANAGER__C': 'Lookup(User)',
#  'PSA_REPORT__RESOURCE_NAME__C': 'Formula (Text)',
#  'PSE__RESOURCE_ROLE__C': 'Picklist',
#  'RETENTION_STAGE__C': 'Picklist',
#  'PSE__REVENUE__C': 'Currency(16, 2)',
#  'ROLE__C': 'Picklist',
#  'ROLE_MARKETO__C': 'Text Area(255)',
#  'SALESFORCE_OLD_ID__C': 'Text(18) (External ID) (Unique Case Sensitive)',
#  'PSE__SALESFORCE_USER__C': 'Lookup(User)',
#  'SALESFORCE_USER_ID__C': 'Text(15)',
#  'SALESFORCE_USER_RECORD__C': 'Lookup(User)',
#  'MKTO_SI__SALES_INSIGHT__C': 'Formula (Text)',
#  'SALES_MATERIALS_OPTIN_MARKETO__C': 'Checkbox',
#  'SALUTATION_MARKETO__C': 'Text Area(255)',
#  'PSE__SCHEDULED_UTILIZATION__C': 'Percent(8, 2)',
#  'PSE__SCHEDULED_UTILIZATION_BILLABLE_HOURS__C': 'Number(16, 2)',
#  'PSE__SCHEDULED_UTILIZATION_CALENDAR_HOURS__C': 'Number(16, 2)',
#  'PSE__SCHEDULED_UTILIZATION_CREDITED_HOURS__C': 'Number(16, 2)',
#  'PSE__SCHEDULED_UTILIZATION_EXCLUDED_HOURS__C': 'Number(16, 2)',
#  'PSE__SCHEDULED_UTILIZATION_HELD_HOURS__C': 'Number(16, 2)',
#  'PSE__SCHEDULED_UTILIZATION_NON_BILLABLE_HRS__C': 'Number(16, 2)',
#  'PSE__SCHEDULED_UTILIZATION_TARGET__C': 'Formula (Percent)',
#  'PSE__SCHEDULED_UTILIZATION_TARGET_ATTAINMENT__C': 'Formula (Percent)',
#  'PSE__SCHEDULED_UTILIZATION_TARGET_HOURS__C': 'Number(16, 2)',
#  'SCHEDULER__C': 'Formula (Text)',
#  'MKTO71_LEAD_SCORE__C': 'Number(10, 0)',
#  'SEGMENTATION__C': 'Picklist',
#  'SERVICE_LEVEL__C': 'Picklist',
#  'SFID__C': 'Text(18)',
#  'SHARING_VIA_E_MAIL__C': 'Formula (Text)',
#  'SHARING_VIA_E_MAIL_AFMO__C': 'Formula (Text)',
#  'SHARING_VIA_FACEBOOK__C': 'Formula (Text)',
#  'SHARING_VIA_FACEBOOK_AFMO__C': 'Formula (Text)',
#  'SHARING_VIA_FACEBOOK_BUSINESS__C': 'Formula (Text)',
#  'SHARING_VIA_FACEBOOK_BUSINESS_AFMO__C': 'Formula (Text)',
#  'SHARING_VIA_LINKEDIN__C': 'Formula (Text)',
#  'SHARING_VIA_LINKEDIN_AFMO__C': 'Formula (Text)',
#  'SHARING_VIA_TWITTER__C': 'Formula (Text)',
#  'SHARING_VIA_TWITTER_AFMO__C': 'Formula (Text)',
#  'SOCIAL_MEDIA_POLICY__C': 'Formula (Text)',
#  'SOCIAL_MEDIA_POLICY_AFMO__C': 'Formula (Text)',
#  'SPECIAL_DEALS__C': 'Checkbox',
#  'SPECIAL_HANDLING__C': 'Text Area(255)',
#  'SPECIAL_OFFERS_OPTIN_MARKETO__C': 'Checkbox',
#  'SSN_TBDEL__C': 'Text(11)',
#  'SSN_LAST_4__C': 'Formula (Text)',
#  'STAFF_OR_WHOLESALER_EMAIL__C': 'Formula (Text)',
#  'STAFF_USER_LICENSE_TYPE__C': 'Formula (Text)',
#  'STAFF_USER_RECORD__C': 'Lookup(User)',
#  'STAFF_USER_RECORD_STATUS__C': 'Formula (Text)',
#  'START_DATE__C': 'Date',
#  'PSE__START_DATE__C': 'Date',
#  'STATE__C': 'Picklist',
#  'STATES_W_ACTIVE_REPS__C': 'Text(255)',
#  'STATES_W_ACTIVE_REPS_AFMO__C': 'Text Area(255)',
#  'SUPPORT__C': 'Checkbox',
#  'SUSPENSION_OVERRIDE_MARKETO__C': 'Checkbox',
#  'TACTICS_LAST_REFRESH__C': 'Formula (Date)',
#  'TACTICS_LAST_REFRESH_AFMO__C': 'Formula (Date)',
#  'TERMINATION_DATE__C': 'Date',
#  'TERMINATION_REASON__C': 'Picklist',
#  'TERRITORY__C': 'Lookup(Territory)',
#  'TERRITORY_ADJUSTMENT__C': 'Picklist',
#  'TERRITORY_ID_STRING__C': 'Text(100)',
#  'TERRITORY_INSTRUCTIONS__C': 'Long Text Area(3200)',
#  'TERRITORY_NAME_MARKETO__C': 'Text(255)',
#  'TERRITORY_NAME__C': 'Formula (Text)',
#  'TERRITORY_OWNER__C': 'Formula (Text)',
#  'TERRITORY_OWNER_ID__C': 'Formula (Text)',
#  'TERRITORY_ROLE__C': 'Formula (Text)',
#  'TERRITORY_STATUS__C': 'Formula (Text)',
#  'TERRITORY_TYPE__C': 'Formula (Text)',
#  'THIS_YEARS_PRODUCTION__C': 'Currency(18, 0)',
#  'THRIVENT_SUBSCRIPTION_ELIGIBLE_MARKETO__C': 'Checkbox',
#  'TIME_ZONE__C': 'Picklist',
#  'TIME_ZONE_2__C': 'Text(5)',
#  'TITLE__C': 'Picklist',
#  'TOP_PRODUCER__C': 'Picklist',
#  'PSE__TOTAL_COSTS__C': 'Formula (Currency)',
#  'TOTAL_SUBMITTED_PREMIUM__C': 'Currency(16, 2)',
#  'TOTAL_ISSUED_PREMIUM__C': 'Currency(16, 2)',
#  'TOTAL_PAID_PREMIUM__C': 'Currency(16, 2)',
#  'PSE__TOTAL_TIME_PERIOD_HOURS__C': 'Number(16, 2)',
#  'TOUCH_LEVEL__C': 'Picklist',
#  'TRAILS__C': 'Percent(18, 0)',
#  'UNIQUE_BD_REP_ID__C': 'Text(50)',
#  'UNIQUE_CONTACTS__C': 'Lookup(Unique Contact Id)',
#  'UNIQUE_CONTACT_ROLE__C': 'Picklist (Multi-Select)',
#  'UNIQUE_ENTERPRISE_CONTACT_ID__C': 'Text(100) (External ID) (Unique Case Sensitive)',
#  'UNSUBSCRIBED_REASON_MARKETO__C': 'Text Area(255)',
#  'UPDATE_DETAILS__C': 'Text Area(255)',
#  'UPDATE_IMPACT_CURRENT_CASES__C': 'Picklist',
#  'URGENCY_MARKETO__C': 'Number(18, 0)',
#  'MKTO_SI__URGENCY__C': 'Formula (Text)',
#  'URGENCY_VALUE_MARKETO__C': 'Number(16, 2)',
#  'MKTO_SI__URGENCY_VALUE__C': 'Number(4, 0)',
#  'USERNAME__C': 'Formula (Text)',
#  'USER_RELATIONSHIP_TYPE__C': 'Formula (Text)',
#  'US_ZIP_CODE__C': 'Lookup(US Zip Code)',
#  'PSE__TOTAL_UTILIZATION__C': 'Percent(8, 2)',
#  'PSE__UTILIZATION__C': 'Formula (Percent)',
#  'PSE__UTILIZATION_ELAPSED_HOURS__C': 'Number(16, 2)',
#  'PSE__UTILIZATION_CALCULATION_DATE__C': 'Date',
#  'PSE__UTILIZATION_LAST_UPDATE_DATE__C': 'Date/Time',
#  'PSE__UTILIZATION_LAST_UPDATED_BY__C': 'Lookup(User)',
#  'PSE__UTILIZATION_FULL_TIME_PERIOD__C': 'Formula (Percent)',
#  'PSE__UTILIZATION_TARGET__C': 'Percent(3, 2)',
#  'PSE__UTILIZATION_TARGET_ATTAINMENT__C': 'Formula (Percent)',
#  'PSE__UTILIZATION_TARGET_AVERAGE__C': 'Formula (Percent)',
#  'PSE__UTILIZATION_TARGET_HOURS__C': 'Number(16, 2)',
#  'VARIABLE_ANNUITY__C': 'Percent(18, 0)',
#  'VARIABLE_LIFE__C': 'Percent(18, 0)',
#  'MKTO_SI__VIEW_IN_MARKETO__C': 'Formula (Text)',
#  'WEALTHVEST_PRODUCER_ID__C': 'Lookup(Contract)',
#  'WEALTHVEST_SUBSCRIPTION_ELIGIBLE_MARKETO__C': 'Checkbox',
#  'WEBINARS_ALLOWED_AFMO__C': 'Formula (Checkbox)',
#  'WEBINARS_ALLOWED__C': 'Formula (Checkbox)',
#  'WEDDING_ANNIVERSARY__C': 'Date',
#  'WELCOME_EMAIL_RECIPIENTS_HIDDEN__C': 'Text(255)',
#  'WHOLESALER_ADVISORIES_LC__C': 'Text Area(255)',
#  'WHOLESALER_ADVISORIES_NB__C': 'Text Area(255)',
#  'WHOLESALER_ALIGNMENT_ISSUE__C': 'Formula (Checkbox)',
#  'WHOLESALER_LLC_NAME__C': 'Text(50)',
#  'WORDPRESS_SECURITY_ROLE__C': 'Picklist',
#  'PSE__WORK_CALENDAR__C': 'Lookup(Work Calendar)',
#  'WRITES_ANNUITIES_MARKETO__C': 'Checkbox',
#  'WRITES_PERSONAL_PRODUCTION__C': 'Picklist',
#  'WSP_APPROVED__C': 'Formula (Checkbox)',
#  'WV_AFFILIATION__C': 'Picklist',
#  'WV_AFMO_AGREEMENT_ID__C': 'Lookup(Contract)',
#  'WV_CARRIER_UPDATE_EMAILS__C': 'Formula (Checkbox)',
#  'WV_EMAIL_DOMAIN__C': 'Picklist (Multi-Select)',
#  'WV_RELATIONSHIP_CHANGE_DETAILS__C': 'Text Area(255)',
#  'WV_REWARDS_SUBSCRIPTION_ELIGIBLE_MARKETO__C': 'Checkbox',
#  'WV_SP_SUB_ELIGIBLE_MARKETO__C': 'Checkbox',
#  'YEARS_LICENSED__C': 'Number(2, 0)',
#  'YTD_FA_SALES__C': 'Currency(16, 2)',
#  'YTD_PROPORTIONAL_EST_PREMIUM__C': 'Currency(16, 2)',
#  'YTD_PROPORTIONAL_ISSUED_PREMIUM__C': 'Currency(16, 2)',
#  'YTD_PROPORTIONAL_PAID_PREMIUM__C': 'Currency(16, 2)',
#  'ZZJEF_TEMP4__C': 'Currency(18, 0)'}

# %%
import json
with open('api-type map.json', 'w') as outfile:
    json.dump(api_2_type_map, outfile)

# %%
non_formula_zero_usage_field = [i for i in zero_usage_field if 'Formula' not in api_2_type_map[i]]

# %%
zero_usage_fields = pd.read_json('0 usage fields.json')

# %%
zero_field_types = {i:j for i,j in api_2_type_map.items() if i in list(zero_usage_fields.to_dict()[0].values())}

# %%
pd.DataFrame({'API Name' : list(zero_field_types.keys()), 'Data Type': list(zero_field_types.values())}).to_csv('0% Usage Fields.csv', index=False)

# %%
pd.read_csv('0% Usage Fields.csv',)
# Out:
#                                      API Name                  Data Type
# 0                      ADDITIONAL_CONTACTS__C               Lookup(Case)
# 1        AFMO_AGENCY_CARRIER_UPDATE_EMAILS__C             Formula (Text)
# 2                           AFMO_RECRUITER__C             Formula (Text)
# 3           ALLIANZ_APPROVED_IC_WHOLESALER__C                   Picklist
# 4                              ANNUITY_ABC__C                   Picklist
# 5   APPROVED_MARKETING_MATERIAL_NOTES_AFMO__C      Long Text Area(32768)
# 6             APPROVED_SALES_CHANNELS_AFMO__C             Formula (Text)
# 7                   AVERAGE_FIA_PRODUCTION__C                   Picklist
# 8                  BASE_SALESFORCE_PROFILE__C                   Picklist
# 9                   BEHAVIOR_SCORE_MARKETO__C              Number(10, 0)
# 10                          BIRTHDAY_MM_DD__C                    Text(5)
# 11                 COMMENT_HISTORY_MARKETO__C      Long Text Area(30000)
# 12                   COMPANY_NOTES_MARKETO__C      Long Text Area(30000)
# 13     DATE_APPROVED_ALLIANZ_IC_WHOLESALER__C                       Date
# 14               DEMOGRAPHIC_SCORE_MARKETO__C              Number(10, 0)
# 15                      DEPARTMENT_MARKETO__C                  Text(255)
# 16                              DEPARTMENT__C                   Picklist
# 17                      DNC_AGREEMENT_NAME__C                   Text(50)
# 18                     DNC_EXPIRATION_DATE__C                       Date
# 19               DO_NOT_CALL_CAUSE_MARKETO__C             Text Area(255)
# 20              DO_NOT_CALL_REASON_MARKETO__C             Text Area(255)
# 21                           DRAW_END_DATE__C                       Date
# 22             EMAIL_INVALID_CAUSE_MARKETO__C             Text Area(255)
# 23                       MKTO_SI__HIDEDATE__C                       Date
# 24        PSA_REPORT__HIST_SCH_UTILIZATION__C          Formula (Percent)
# 25                      IP_ADDRESS_MARKETO__C             Text Area(255)
# 26          APPIRIO_CORE__LAST_ACCESS_DATE__C                  Date/Time
# 27                       LAST_INFOSEC_DATE__C                       Date
# 28    LAST_INTERESTING_MOMENT_DATE_MARKETO__C                  Date/Time
# 29    LAST_INTERESTING_MOMENT_DESC_MARKETO__C      Long Text Area(30000)
# ..                                        ...                        ...
# 45                   PERSON_STATUS_MARKETO__C             Text Area(255)
# 46                       APPIRIO_CORE__PIN__C             Text Area(255)
# 47                             PREFERENCES__C             Text Area(255)
# 48        PREFERRED_CONTACT_METHOD_MARKETO__C             Text Area(255)
# 49                        PRIORITY_MARKETO__C              Number(18, 0)
# 50                 PRODUCTION_CREDITS_AFMO__C             Formula (Text)
# 51                  RELATIVE_SCORE_MARKETO__C              Number(18, 0)
# 52            RELATIVE_SCORE_VALUE_MARKETO__C              Number(18, 0)
# 53                RELATIVE_URGENCY_MARKETO__C              Number(18, 0)
# 54                         REP_CRD_MARKETO__C              Number(18, 0)
# 55                      SALUTATION_MARKETO__C             Text Area(255)
# 56                               SCHEDULER__C             Formula (Text)
# 57                 SHARING_VIA_E_MAIL_AFMO__C             Formula (Text)
# 58               SHARING_VIA_FACEBOOK_AFMO__C             Formula (Text)
# 59      SHARING_VIA_FACEBOOK_BUSINESS_AFMO__C             Formula (Text)
# 60               SHARING_VIA_LINKEDIN_AFMO__C             Formula (Text)
# 61                SHARING_VIA_TWITTER_AFMO__C             Formula (Text)
# 62                SOCIAL_MEDIA_POLICY_AFMO__C             Formula (Text)
# 63                        SPECIAL_HANDLING__C             Text Area(255)
# 64               STATES_W_ACTIVE_REPS_AFMO__C             Text Area(255)
# 65               TACTICS_LAST_REFRESH_AFMO__C             Formula (Date)
# 66                                   TITLE__C                   Picklist
# 67                         UNIQUE_CONTACTS__C  Lookup(Unique Contact Id)
# 68                         URGENCY_MARKETO__C              Number(18, 0)
# 69                   URGENCY_VALUE_MARKETO__C              Number(16, 2)
# 70                             US_ZIP_CODE__C        Lookup(US Zip Code)
# 71                     WHOLESALER_LLC_NAME__C                   Text(50)
# 72                          WV_AFFILIATION__C                   Picklist
# 73                    WV_AFMO_AGREEMENT_ID__C           Lookup(Contract)
# 74                          YEARS_LICENSED__C               Number(2, 0)
#
# [75 rows x 2 columns]
